# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanzricardo/bds/blob/main/Modulo_R_Lista_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Introdução à linguagem R para análise de dados**
# Autoria: Ivan Zimmermann, Departamento de Saúde Coletiva, Universidade de Brasília (ivan.zimmermann@unb.br)
#
# **Aula: Vetores na linguagem R**
#
# Um dos elementos fundamentais na liguagem é o trabalho com objetos (variáveis armazenadas na memória). Nesta lista vamos trabalhar com vários aspectos dos objetos em R.

# %% [markdown]
# **Criando vetores**
#
# Na linguagem vamos lidar com estruturas diferentes de objetos. Um objeto essencial é o vetor. O vetor armazena em um único local um valor ou uma sequência ordenada de valores. Para armazenar valores em um objeto, utilizamos os sinais de atribuição (<- ou =). Em relação a valores, lidamos com alguns tipos básicos de dados em R:
#
# ![image.png](data:image/png;base64,...)
#
# **DICAS**
#
# 1) É possível identificar o tipo e estrutura dos dados com a função str()
#
# 2) Dados de texto (strings) são armazenamos com a indicação de aspas (" ")
#
#
# 3) O nome do objeto não pode começar com um número e não pode usar alguns símbolos especiais: ^,!, $, @, +, -, / ou *

# %% [markdown]
# *Exercício 2.1: Execute as operações solicitadas*

# %%
#Crie um vetor chamado idades com os valores 42, 18, 32, 58, 74 e 87
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Verifique a estrutura, classe e tipo dos dados no vetor idades
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Crie um vetor chamado idades com os valores 42, "dezoito", 32, 58, 74 e 87
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Verifique a estrutura, classe e tipo dos dados no vetor idades
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Crie um vetor chamado peso com o valor 78 e um vetor chamado altura com valor 1.73
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Relembrando que o índice de massa corporal (IMC) é obtido pela divisão do peso (em kilogramas) pela altura (em metros) ao quadrado
#Crie um objeto chamado IMC referente à equação de cálculo do IMC que considere os objetos criados anteriormente
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Atualize os valores dos objetos altura e peso para 1.65 e 58, respectivamente. Após, rode o código anterior do cálculo do IMC
### INSIRA SUA RESPOSTA AQUI ###

# %% [markdown]
# **Operações básicas com Vetores**
#
# Na manipulação de dados com R, precisamos executar constantemente algumas operações básicas com vetores. Algumas destas operações são:
#
# ![image.png](data:image/png;base64,...)
#
# **DICAS**
#
# 1) A função sample() gera uma amostra aleatória sem repsição de valores de um objeto. Basta indicar nos argumentos o objeto e o tamanho da amostra
#
# 2) A função length() identifica o tamanho de um vetor
#
# 3) A função is.na() verifica a condição de um valor ser ausente (NA)

# %% [markdown]
# *Exercício 2.2: Execute as operações solicitadas*

# %%
#Crie um vetor chamado id que armazene uma sequência de 1 a 60
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Crie um vetor chamado amostra que armazene uma amostra aleatória de 20 valores do objeto id
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Acesse o quinto elemento da amostra
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Altere o sétimo elemento pelo valor 99
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Defina como ausentes os valores iguais a 99
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Quantos valores da amostra são maiores que 15?
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Exclua os valores maiores que 15 nesta amostra
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Determine a posição dos valores ausentes na amostra
### INSIRA SUA RESPOSTA AQUI ###

# %% [markdown]
# **Aplicando funções a Vetores**
#
# Além das operações básicas de manipulação de dados, precisamos continuamente aplicar funções em vetores no R. Algumas das funções essenciais são:
#
# ![image.png](data:image/png;base64,...)
#
# **DICAS**
#
# 1) O operador %% traz o resto de uma divisão. Exemplo: 10 %% 2 = 0 e 10 %% 3 = 1

# %% [markdown]
# *Exercício 2.3: Excute as operações solicitadas*

# %%
#Crie um vetor chamado id que armazene uma sequência de 100 a 1000 em intervalos de 15 elementos
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Crie um vetor chamado amostra que armazene uma amostra aleatória de 50 valores do objeto id
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Identifique a posição do maior valor da amostra
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Calcule a média amostral
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Calcule o desvio padrão da amostra com 2 casas decimais
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Calcule a soma dos valores entre 200 e 300
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Apresente um resumo de medidas dos valores pares
### INSIRA SUA RESPOSTA AQUI ###

# %% [markdown]
# # **Referências**
#
# Alcoforado LF. Utilizando A Linguagem R: Conceitos, manipulação, visualização, modelagem e elaboração de relatórios. Rio de Janeiro: Alta Book, 2021. 367p
#
# Figueira L. Criando funções no R. Estatística é com R! Disponível em: http://www.estatisticacomr.uff.br/?p=224
#
# Grolemund G. Hands-On Programming with R. O'Reilly Media; 1ª edição, 2014. Disponível em: https://rstudio-education.github.io/hopr
#
# Wickham H. Advanced R. CRC Press; 1ª edição, 2014. Disponível em: http://adv-r.had.co.nz/
