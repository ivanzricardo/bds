# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanzricardo/bds/blob/main/Modulo_R_Lista_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Introdução à linguagem R para análise de dados**
# Autoria: Ivan Zimmermann, Departamento de Saúde Coletiva, Universidade de Brasília (ivan.zimmermann@unb.br)
#
# **Aula 1: Fundamentos da linguagem R**
#
# Mais que um software estatístico, R é uma linguagem de programação com ampla aplicação na obtenção, tratamento, análise e visualização de dados. Iniciaremos aqui os nossos estudos com exercícios aplicados aos conceitos e recursos introdutórios da linguagem R, os quais estabelecerão as bases para que você se aproprie e desenvolva suas habilidades de forma independente.
#
#
# **Operadores matemáticos**
#
# Vamos começar com algumas operações básicas em R:
#
# ![image.png](data:image/png;base64,...)
#
# **DICAS:**
#
# 1) O uso do símbolo # (numeral) permite inserirmos comentários ao longo do código. Tudo que vier após o # não será executado como código
#
# 2) Use os comandos CTRL + ENTER para executar as células de código
#
# 3) Faça bom uso de parênteses () para a correta ordem de operações matemáticas
#
# 4) R usa o ponto (.) como separador dos decimais. Caso queira os resultados de decimais com vírgula, use a função options(OutDec=",")

# %% [markdown]
# *Exercício 1.1: Execute as operações solicitadas*

# %%
#Calcule a soma dos números 245 e 300
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Calcule a subtração entre os números 50 e 23
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Calcule a multiplicação entre os números 20 e 43
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Calcule a divisão entre os números 150 e 24
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Calcule a potenciação de 5 elevado ao cubo
### INSIRA SUA RESPOSTA AQUI ###

# %%
#O índice de massa corporal (IMC) é um indicador obtido pela divisão do peso (em kilogramas) pela altura (em metros) ao quadrado
#Calculo o IMC de um adutlto com 1,73 de altura e 78 Kg de peso corpóreo
### INSIRA SUA RESPOSTA AQUI ###

# %% [markdown]
# **Operadores lógicos**
#
# Ao longo de nossos códigos será essencial o uso de operadores lógicos, sobretudo ao construirmos filtros de dados. Abaixo, temos um levantamento dos principais operadores lógicos disponíveis em R:
#
# ![image.png](data:image/png;base64,...)
#
# **DICAS:**
#
# 1) Lembre-se de que esse operadores retornam como resultado os valores TRUE e FALSE

# %% [markdown]
# *Exercício 1.2: Excute as operações solicitadas*

# %%
#Verifique se o valor 0.25 é igual a 1/4
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Verifique se o valor 0.25 é diferente de 1/4
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Verifique se o valor 1/10 é maior que 0.10
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Verifique se o valor 1/10 é maior ou igual a 0.10
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Verifique se o valor 1/10 é maior ou igual a 0.10 e menor que 0.05
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Verifique se o valor 1/10 é maior ou igual a 0.10 ou menor que 0.05
### INSIRA SUA RESPOSTA AQUI ###

# %% [markdown]
# **Operadores condicionais**
#
# Ao conciliar os operadores lógicos com algumas funções condicionais, teremos uma ferramenta poderosa para manipular nossos dados. Abaixo, temos um levantamentos de algumas funções matemáticas básicas disponíveis em R:
#
# ![image.png](data:image/png;base64,...)
#
# **DICAS**:
#
# 1) Usaremos if() { } else { } na criação de funções e ifelse() na manipulação de dados

# %% [markdown]
# *Exercício 1.3: Execute as operações solicitadas*

# %%
#Dado que o resultado de um teste para COVID-19 teve resultado de 82 UI, execute a operação que retorna o texto "COVID-19 confirmada" quando 82 é maior ou igual a 79,9
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Execute a operação que retorna o texto "COVID-19 confirmada" quando 82 é maior ou igual a 79,9 e o texto "COVID-19 descartada" quando 82 é menor que 79,9
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Verifique as codições citadas em um paciente que teve o resultado de 64 UI
### INSIRA SUA RESPOSTA AQUI ###

# %% [markdown]
# **Funções matemáticas**
#
# Podemos reconhecer uma função na linguagem R pelo uso de parênteses "()". Ex: o código "log10()" é uma função do R que aplica o logaritmo na base 10. Abaixo, temos um levantamentos de algumas funções matemáticas básicas disponíveis em R:
#
# ![image.png](data:image/png;base64,...)
#
# **DICAS:**
#
# 1) É possível intercalar as funções. Ex: a expressão abs(log(0,9)) retorna o valor absoluto do logaritmo natural de 0,9

# %% [markdown]
# *Exercício 1.4: Excute as operações solicitadas*

# %%
#Calcule a raiz quadrada de 93
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Calcule logaritmo natural de 0.9
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Calcule módulo (valor absoluto) do logaritmo natural de 0.9
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Calcule a raiz quadrada do módulo (valor absoluto) do logaritmo natural de 0.9
### INSIRA SUA RESPOSTA AQUI ###

# %%
#Na geometria euclidiana, o teorema de Pitágoras afirma que: 
#“Em qualquer triângulo retângulo, o quadrado do comprimento da hipotenusa é igual à soma dos quadrados dos comprimentos dos catetos.”
#Calcule a hipotenusa de um triâncgulo retângulo com os catetos iguais 4 e 5
### INSIRA SUA RESPOSTA AQUI ###

# %% [markdown]
# # **Referências**
#
# Alcoforado LF. Utilizando A Linguagem R: Conceitos, manipulação, visualização, modelagem e elaboração de relatórios. Rio de Janeiro: Alta Book, 2021. 367p
#
# Figueira L. Criando funções no R. Estatística é com R! Disponível em: http://www.estatisticacomr.uff.br/?p=224
#
# Grolemund G. Hands-On Programming with R. O'Reilly Media; 1ª edição, 2014. Disponível em: https://rstudio-education.github.io/hopr
#
# Wickham H. Advanced R. CRC Press; 1ª edição, 2014. Disponível em: http://adv-r.had.co.nz/
